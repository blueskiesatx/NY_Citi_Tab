# %%
import pandas as pd
import os
#from zipfile import Zipfile
#from urllib.request import urlopen
#import pymysql
#import csv

#URLs = ['https//s3.amazonaws.com/tripdata/201901-citibike-trip-data.csv.zip']
#dfs = []
#ran fine with data_env2

# %%
#Working backwards from 2019 Feb
feb_path = "Resources/JC-201902-citibike-tripdata.csv"
df_feb = pd.read_csv(feb_path)
df_feb.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
jan_path = "Resources/201901.csv"
df_jan = pd.read_csv(jan_path)
df_jan.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
#for URL in URLs:
    #url = open(URL)
    #output = open('zipFile.zip','wb')
    #output.write(url.read())
    #output.close
    #df = pd.read.csv(zipFile.zip')
            #         dfs.append(df)
#df.head(10)

# %%
##csv_file = "../Resources/customer_data.csv"
##customer_data_df = pd.read_csv(csv_file)
##customer_data_df.head()
path_dec = "Resources/JC-201902-citibike-tripdata.csv"
df_dec = pd.read_csv(path_dec)
df_dec.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
path_nov = "Resources/JC-201811-citibike-tripdata.csv"
df_nov = pd.read_csv(path_nov)
df_nov.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1           278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2           115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3           155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4            82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
oct_path = "Resources/JC-201810-citibike-tripdata.csv"
df_oct = pd.read_csv(oct_path)
df_oct.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1           122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2           211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3           342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4          2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
#That's enough for this date range. Can add more later.

#march_path = "Resources/JC-201803-citibike-tripdata.csv"
#df_march = pd.read_csv(march_path)
#df_march.head()

# %%
#combine the data into one big df. Using shorter timeframe.

#df_year = pd.concat([df_jan, df_feb,df_march,df_april,df_may,df_june,
#                     df_july,df_aug,df_sep,df_oct,df_nov,df_dec],ignore_index=True)
df_winter = pd.concat([df_oct,df_nov,df_dec,df_jan, df_feb],ignore_index=True)

# %%
df_winter.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1           122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2           211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3           342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4          2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
df_winter.to_csv("Resources/citibike_winter.csv" ,index=False)
